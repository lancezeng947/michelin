# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests
import re
import unicodedata

# %%
restaurant_url = 'https://guide.michelin.com/en/california/san-francisco/restaurant/omakase'

# %%
restaurant_page = requests.get(restaurant_url)

# %%
soup = BeautifulSoup(restaurant_page.text, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="full-screen-mobile" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=0" name="viewport"/>
# <meta content="" name="author"/>
# <meta content="#bd2333" name="theme-color"/>
# <meta content="vFUp7XI3G-xKLevkT2qftuscMInOxirdCu0oYr7_uLM" name="google-site-verification">
# <meta content="eZwPBJ-0r-9qysyJy_aEPti-m_vr-h_oUJy2qUR1144" name="google-site-verification">
# <meta content="https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/477464_5.jpg" itemprop="image">
# <meta content="Article" property="og:type">
# <meta content="MICHELIN Guide" property="og:site_name"/>
# <meta content="https://guide.michelin.com/en/california/san-francisco/restaurant/omakase" property="og:url"/>
# <meta content="https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/477464_5.jpg" property="og:image"/>
# <meta content="Omakase – San Francisco - a MICHELIN Guide Restaurant" itemprop="name"/>
# <meta content="Omakase – San Francisco - a MICHELIN Guide Restaurant" property="og:title">
# <title>Omakase – San Francisco - a MICHELIN Guide Restaurant</title>
# <meta content="Omakase – a 1 Star MICHELIN restaurant in the 2019 MICHELIN Guide California. The MICHELIN inspectors’ point of view, information on prices, types of cuisine and opening hours on the MICHELIN Guide's official website" itemprop="description"/>
# <meta content="Omakase – a 1 Star MICHELIN restaurant in the 2019 MICHELIN Guide California. The MICHELIN inspectors’ point of view, information on prices, types of cuisine and opening hours on the MICHELIN Guide's official website" property="og:description">
# <meta content="Omakase – a 1 Star MICHELIN restaurant in the 2019 MICHELIN Guide California. The MICHELIN inspectors’ point of view, information on prices, types of cuisine and opening hours on the MICHELIN Guide's official website" name="description"/>
# <meta content="michelin_revamp" name="layout">
# <link href="https://guide.michelin.com/en/california/san-francisco/restaurant/omakase" rel="canonical"/>
# <link href="https://guide.michelin.com/us/en/california/san-francisco/restaurant/omakase" hreflang="en-us" rel="alternate"/>
# <link href="https://guide.michelin.com/us/zh_CN/california/san-francisco/restaurant/omakase" hreflang="zh-us" rel="alternate"/>
# <link href="https://guide.michelin.com/us/es/california/san-francisco/restaurante/omakase" hreflang="es-us" rel="alternate"/>
# <link href="https://guide.michelin.com/en/california/san-francisco/restaurant/omakase" hreflang="x-default" rel="alternate"/>
# <title>MICHELIN Guide - the official website</title>
# <link href="/assets/favicon/favicon-1.png" rel="apple-touch-icon"/>
# <link href="/assets/favicon/favicon-1.png" rel="icon" sizes="48x53" type="image/png"/>
# <link href="/manifest.json" rel="manifest"/>
# <link as="font" crossorigin="" href="/assets/web/fonts/annuel/Annuels-b8bdb9951dba18a04c14aa0293712e27.woff" rel="preload" type="font/woff"/>
# <link as="font" crossorigin="" href="/assets/web/fonts/Open_Sans/opensans-semibold-webfont-59da2bf12314940ba8845a665fa4fd6f.woff2" rel="preload" type="font/woff2"/>
# <!-- Font awesome -->
# <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.8.2/css/all.css" integrity="sha384-xVVam1KS4+Qt2OrFa+VdRUoXygyKIuNWUUUBZYv+n27STsJ7oDOHJgfF0bNKLMJF" rel="stylesheet"/>
# <!-- End awesome -->
# <link href="/assets/web/app.restaurant-09c4af60401a4697752ab15e3aceabb3.css" rel="stylesheet">
# <noscript>
# <link href="/assets/web/frontend/noscript-b8bc3e39b6a125851efedf5c32059361.css" rel="stylesheet">
# </link></noscript>
# <!-- Global JS variables start -->
# <script type="text/javascript">
#         var COOKIE_SECURE = true;
#         var GTM_ENVIRONMENT = 'Prod';
#         var DISABLE_ADS = true;
#         var ALGOLIASEARCH_APP_ID = '8NVHRD7ONV';
#         var ALGOLIASEARCH_SEARCH_KEY = '71b3cff102a474b924dfcb9897cc6fa8';
#         dataLayer = [];
#         dLayer = {};
#     </script>
# <!-- Global JS variables end -->
# <!-- Dynamic Tag Management -->
# <script src="//assets.adobedtm.com/36bbd2c3081fb00e1c38abf086f0d9f02eb7a84f/satelliteLib-46aa90256b65d73f774c22fbe54a33ea83656eca.js"></script>
# <!-- End Dynamic Tag Management -->
# <script>
#     var _gtmEnvironment = typeof GTM_ENVIRONMENT !== 'undefined' ? GTM_ENVIRONMENT : 'Dev';
#
#
#         dLayer = {
#             'environment': _gtmEnvironment,
#             'event': 'Country.Global.en',
#             'category': 'restaurant.datasheet',
#             'cookingtype': 'japanese',
#             'country' : 'en',
#             'region': 'California',
#             'city': 'San Francisco',
#             'district': 'SoMa',
#             'distinction': '3 star',
#             'guide' : 'Global',
#             'id': '6947',
#             'restaurant_name': 'Omakase',
#             'chef': 'none',
#             'price': 'none',
#             'language': 'en',
#             'online_booking': 'False'
#         };
#
#
#     dataLayer.push(dLayer);
# </script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-NND8XGT');</script>
# <!-- End Google Tag Manager -->
# <script type="text/javascript">
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#
#             googletag.cmd.push(function() {
#                 googletag.pubads().enableSingleRequest();
#                 googletag.enableServices();
#             });
#
#     </script>
# <script>
#             (function(b,o,i,l,e,r){b.GoogleAnalyticsObject=l;b[l]||(b[l]=
#                 function(){(b[l].q=b[l].q||[]).push(arguments)});b[l].l=+new Date;
#                 e=o.createElement(i);r=o.getElementsByTagName(i)[0];
#                 e.src='https://www.google-analytics.com/analytics.js';
#                 r.parentNode.insertBefore(e,r)}(window,document,'script','ga'));
#             ga('create','UA-76077827-8');ga('send','pageview');
#         </script>
# </link></meta></meta></meta></meta></meta></meta></meta></head>
# <body class="lang-en">
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-NND8XGT" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
# <!--[if lt IE 10]>
#   <p class="browserupgrade">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade your browser</a> to improve your experience.</p>
# <![endif]-->
# <!-- Start Navbar -->
# <header class="header-wrapper">
# <nav class="d-flex header js-header">
# <!-- Start Logo -->
# <div class="header__logo">
# <a aria-label="Homepage" href="/en"></a>
# </div>
# <div class="header__toggle-search">
# <i class="far fa-arrow-left"></i>
# </div>
# <form action="/en/search" class="header__search js-header-search" data-suggest-url="/en/suggestion" method="get">
# <div class="input-group input-search">
# <!-- Start Input Search -->
# <div class="input-group input-search">
# <div class="typeahead__container flex-fill js-autocomplete__container">
# <div class="typeahead__field">
# <div class="js-autocomplete__search_box" data-gtm-country="en" data-gtm-guide="Global" data-language="en" data-language-base="/en" data-location-icon="fa-map-marker-alt" data-location-index="prod-locations" data-location-label="Locations" data-restaurant-icon="fa-utensils" data-restaurant-index="prod-restaurants-en" data-restaurant-label="Restaurants" data-restaurants-base="/en/restaurants" data-search-restaurant="/en/search?type=restaurant" data-site-code="global" data-site-level="GLOBAL" data-site-name="Global">
# <label class="sr-only" for="main-search">Search</label>
# <i class="fal fa-search search-icon"></i>
# <input autocomplete="off" class="form-control js-search__field js-typeahead__header" data-country="en" data-guide="Global" id="main-search" name="q" placeholder="Search for Restaurants, Chefs …" type="text" value=""/>
# <span class="typeahead__crosshair hidden">
# <i class="icon fal fa-crosshairs"></i>
# </span>
# <span class="typeahead__cancel-button js-autocomplete__search_cancel" style="opacity: 0;">×</span>
# </div>
# </div>
# <div class="typeahead__result js-autocomplete__search_results">
# <div class="typeahead__list js-autocomplete__search_hits"></div>
# </div>
# </div>
# </div>
# <!-- Start Input Search -->
# </div>
# </form>
# <!-- Start Toggle Search -->
# <div class="header__toggle-search-button">
# <a class="js-toggle-search" href="#"><i class="fal fa-search"></i></a>
# </div>
# <!-- End Toggle Search -->
# <div class="header__location">
# <a data-target="#exampleModal" data-toggle="modal" href="#">
# <span class="fal fa-map-marker-alt header__location-icon"></span>
# <span class="header__location-dekstop-text">Global <span></span> English</span>
# <span class="header__location-not-dekstop-text">Select</span>
# </a>
# </div>
# <!-- Start Toggle -->
# <div class="header__toggle">
# <button aria-label="Menu" class="button js-open-sidebar js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.menu" data-guide="Global" type="button">
# <span class="button__icon">
# <i class="icon mg-burger"></i>
# </span>
# <span class="button__menu-button-label">Menu</span>
# </button>
# </div>
# <!-- End Toggle -->
# </nav>
# </header>
# <!-- End Navbar -->
# <!-- Start Sidebar -->
# <div class="sidebar">
# <div class="sidebar__backdrop js-close-sidebar js-gtm-link" data-event="Menu.close" data-page-name="restaurant.datasheet"></div>
# <div class="sidebar__wrapper">
# <div class="sidebar__header">
# <div class="sidebar__logo"><img alt="Michelin Guide" class="lazy" data-src="/assets/images/michelin-guide-logo-white.svg"/></div>
# <button aria-label="Close Menu" class="button button--size-normal button--transparent button--icon button--icon-only js-close-sidebar js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.close" data-guide="Global" type="button">
# <span class="button__icon">
# <i class="fal fa-times"></i>
# </span>
# </button>
# </div>
# <div class="sidebar__content">
# <div class="sidebar__data-location">
# <i class="fal fa-map-marker-alt"></i>
# <a class="white js-open-selection" data-target="#exampleModal" data-toggle="modal" href="#">Global | English</a>
# </div>
# <a class="sidebar__content-link js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.Restaurants" data-guide="Global" href="/en/restaurants" target="_self">Restaurants</a>
# <a class="sidebar__content-link js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.Hotels" data-guide="Global" href="https://www.tablethotels.com" rel="nofollow noopener" target="_blank">Hotels</a>
# <a class="sidebar__content-link js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.Magazine" data-guide="Global" href="/en/articles" target="_self">Magazine</a>
# <a class="sidebar__content-link js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.Events" data-guide="Global" href="/en/events" target="_self">Events</a>
# <a class="sidebar__content-link js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="Menu.Subscribe to newsletter" data-guide="Global" href="/en/subscribe" target="_self">Subscribe to newsletter</a>
# <div class="sidebar__widget">
# <h4 class="sidebar__content-title">EXPERIENCE THE MICHELIN GUIDE SELECTION</h4>
# <a class="sidebar__filter-link" href="/us/en/new-york-state/restaurants">
# <i class="fal fa-map-marker-alt"></i>
#                         Restaurants in New York State
#                     </a>
# <a class="sidebar__filter-link" href="/us/en/washington/washington-dc/restaurants">
# <i class="fal fa-map-marker-alt"></i>
#                         Restaurants in Washington, D.C.
#                     </a>
# <a class="sidebar__filter-link" href="/us/en/illinois/chicago/restaurants">
# <i class="fal fa-map-marker-alt"></i>
#                         Restaurants in Chicago
#                     </a>
# </div>
# <div class="share-block">
# <a aria-label="Follow us on Facebook" class="share-block__icon-img" href="https://www.facebook.com/MichelinGuideUnitedStates" rel="nofollow noopener" target="_blank">
# <img alt="" class="lazy" data-src="/assets/images/social-network/facebook_white.svg"/>
# </a>
# <a aria-label="Follow us on Instagram" class="share-block__icon-img" href="https://www.instagram.com/michelinguide" rel="nofollow noopener" target="_blank">
# <img alt="" class="lazy" data-src="/assets/images/social-network/instagram_white.svg"/>
# </a>
# <a aria-label="Follow us on Youtube" class="share-block__icon-img" href="https://www.youtube.com/channel/UCy_N8T7LvN5Dwi7LjLCZnhg" rel="nofollow noopener" target="_blank">
# <img alt="" class="lazy" data-src="/assets/images/social-network/youtube_white.svg"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# <!-- End Sidebar -->
# <main>
# <!-- Start Breadcrumb -->
# <div class="wrap-breadcrumb js-breadcrumb">
# <ol class="breadcrumb"><li class="breadcrumb-item"><a href="/en">MICHELIN Guide Global</a></li><li class="breadcrumb-item"><a href="/en/us/restaurants">United States<li class="breadcrumb-item"><a href="/en/us/california/restaurants">California</a></li><li class="breadcrumb-item"><a href="/en/us/california/san-francisco/restaurants">San Francisco Restaurants</a></li><li class="breadcrumb-item active">
#         Omakase
#     </li></a></li></ol>
# </div>
# <!-- End Breadcrumb -->
# <!-- Start Masthead -->
# <div class="masthead masthead__gallery masthead__restaurant js-masthead-gallery">
# <div class="masthead__gallery-overlay"></div>
# <div class="masthead__gallery-wrapper js-gallery-wrapper">
# <button class="masthead__gallery-open js-gallery-button" data-target="#galleryPopupMasthead" data-toggle="modal" type="button">
# <span class="masthead__gallery-open--number">
#                 15
#             </span>
# <span class="masthead__gallery-open--base"></span>
# </button>
# <div class="masthead__gallery-image">
# <div class="masthead__gallery-image-item js-bg-blur lazy" data-bg="url(https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/477464_5.jpg)" data-image="https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/477464_5.jpg" data-target="#galleryPopupMasthead" data-toggle="modal">
# <noscript><img alt="" src="https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/477464_5.jpg"/></noscript>
# </div>
# <div class="masthead__gallery-image-item js-bg-blur lazy" data-bg="url(https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/477464_6.jpg)" data-image="https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/477464_6.jpg" data-target="#galleryPopupMasthead" data-toggle="modal">
# <noscript><img alt="" src="https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/477464_6.jpg"/></noscript>
# </div>
# <div class="masthead__gallery-image-item js-bg-blur lazy" data-bg="url(https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/477464_7.jpg)" data-image="https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/477464_7.jpg" data-target="#galleryPopupMasthead" data-toggle="modal">
# <noscript><img alt="" src="https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/477464_7.jpg"/></noscript>
# </div>
# </div>
# </div>
# </div>
# <!-- End Masthead -->
# <div class="restaurant-details">
# <div class="container">
# <div class="row">
# <div class="col-xl-4 order-xl-8 col-lg-5 order-lg-7 restaurant-details__aside">
# <!-- Start restaurant detail heading mobile -->
# <div class="restaurant-details__heading d-lg-none">
# <div class="restaurant-details__heading--label d-flex">
# <div class="restaurant-details__heading--label-icon"><i class="fa-michelin color-primary">m</i></div>
# <div class="restaurant-details__heading--label-title">
#                             MICHELIN Guide 2019</div>
# </div>
# <h2 class="restaurant-details__heading--title">Omakase</h2>
# <ul class="restaurant-details__heading--list">
# <li><i class="fal fa-map-marker-alt"></i>665 Townsend St., San Francisco, 94103, United States</li>
# <li class="restaurant-details__heading-price">
#
#                                 75
#
#                                 -
#                                 150
#
#                                 USD
#
#                                  • Japanese
#                             </li>
# </ul>
# </div>
# <!-- End restaurant detail heading mobile -->
# <!-- Start restaurant Booking -->
# <div class="restaurant-details__booking--wrapper js-booking-sticky">
# <div class="restaurant-details__booking--container">
# <div class="restaurant-details__booking">
# <div class="restaurant-details__booking--title-wrapper">
# <h6 class="restaurant-details__booking--title">
#                                     Reservations are not available for this restaurant on our site
#                                 </h6>
# <a class="btn btn-primary btn-block" href="/en/restaurants/japanese">Find similar restaurants</a>
# </div>
# </div>
# </div>
# </div>
# <!-- End restaurant Booking -->
# </div>
# <div class="col-xl-8 col-lg-7">
# <!-- Start Section -->
# <section class="section section-main restaurant-details__main">
# <!-- Start restaurant detail heading desktop -->
# <div class="restaurant-details__heading d-none d-lg-block">
# <div class="restaurant-details__heading--label d-flex">
# <div class="restaurant-details__heading--label-icon"><i class="fa-michelin color-primary">m</i></div>
# <div class="restaurant-details__heading--label-title">
#                                 MICHELIN Guide 2019
#                             </div>
# </div>
# <h2 class="restaurant-details__heading--title">Omakase</h2>
# <ul class="restaurant-details__heading--list">
# <li><i class="fal fa-map-marker-alt"></i>665 Townsend St., San Francisco, 94103, United States</li>
# <li class="restaurant-details__heading-price">
#
#                                     75
#
#                                     -
#                                     150
#
#                                     USD
#
#                                      • Japanese
#                                 </li>
# </ul>
# </div>
# <!-- End restaurant detail heading desktop -->
# <!-- Start restaurant detail description -->
# <div class="restaurant-details__description">
# <div class="restaurant-details__description--heading">
# <h5 class="restaurant-details__description--heading-title restaurant-details__description--heading-title-with-image">
#                                 MICHELIN Guide’s Point Of View
#                             </h5>
# <div class="restaurant-details__description--heading-image">
# <img alt="" class="lazy" src="/assets/images/bib-gourmand-d429a4281185b59c29095a92fc956b09.jpeg">
# <noscript><img alt="" src="/assets/images/bib-gourmand-d429a4281185b59c29095a92fc956b09.jpeg"/></noscript>
# </img></div>
# </div>
# <div class="restaurant-details__description--text js-show-description" data-truncate="100">
# <div class="js-show-description-text">
# <p>True, the vibe is friendly and the location is convenient for tech entrepreneurs, but superb Edomae sushi is the real reason why Omakase is always full. Ergo, reservations are required and punctuality is a must. The kimono-clad servers strain to place dishes in front of diners, who usually sit elbow-to-elbow at the tight L-shaped counter, but the chummy young professionals and gourmands don’t seem to notice anything but the chefs. Choose from two omakase menus; the more extensive (and expensive) one offers additional sashimi and nigiri. Begin with buttery ocean trout steamed in sake and presented with a wedge of heirloom black tomato as well as an herb salad in rice wine vinaigrette. Beautifully arranged sashimi features bluefin tuna with red-fleshed sea perch, garnished with cured kombu, shiso leaf, wasabi and a bit of chrysanthemum petal salad. Still, no dish can compare with the exquisite level of nigiri, which may showcase marinated chutoro, cedar-torched sea bream, Hokkaido uni with house-brined ikura and a fluffy piece of lobster-infused tamago. Extreme attention to detail is the hallmark of dining here, with customized portions of rice and wasabi adjustments for each guest's palate.</p>
# </div>
# <a class="restaurant-details__description-show-button js-show-description-button" href="javascript:void(0)">
#                                 Show More</a>
# <a class="restaurant-details__description-less-button js-less-description-button" href="javascript:void(0)">
#                                 Show Less</a>
# </div>
# </div>
# <!-- End restaurant detail description -->
# <!-- Start restaurant detail classification -->
# <div class="restaurant-details__classification" id="experience-section">
# <ul class="restaurant-details__classification--list">
# <li>
# <i class="fa-michelin restaurant-details__classification--list-icon color-primary">m</i>
#                                 One Star • High quality cooking, worth a stop
#                             </li>
# <li>
# <i class="fa-michelin restaurant-details__classification--list-icon color-primary">ò</i>
#                                     Comfortable. Our most delightful places
#                                 </li>
# </ul>
# </div>
# <!-- End restaurant detail classification -->
# </section>
# <!-- End Section -->
# <!-- Start Section -->
# <section class="section-main">
# <div class="restaurant-details__services">
# <div class="section-header have-slider-nav">
# <h2 class="section__heading_title">Facilities &amp; Services</h2>
# </div>
# <ul class="row restaurant-details__services--list js-show-more" data-visible="4">
# <li>
# <div class="restaurant-details__services--content">
# <i class="fa-michelin color-primary restaurant-details__services--icon">a</i>
#                                                 Wheelchair accessible
#                                             </div>
# </li>
# <li>
# <div class="restaurant-details__services--content">
# <i class="fa-michelin color-primary restaurant-details__services--icon">E</i>
#                                                 Establishment totally or partly reserved for non-smokers
#                                             </div>
# </li>
# </ul>
# <div class="clearfix"></div>
# <div class="restaurant-details__services--action js-services-action">
# <a class="restaurant-details__services--action-show js-show-more-button" href="javascript:void(0)">
#                                     Show More</a>
# <a class="restaurant-details__services--action-less js-show-less-button" href="javascript:void(0)">
#                                     Show Less</a>
# </div>
# </div>
# </section>
# <!-- End Section -->
# <!-- Start Section -->
# <section class="section-main">
# <div class="section-header have-slider-nav">
# <h2 class="section__heading_title">Information</h2>
# </div>
# <div class="row">
# <div class="col-md-6">
# <div class="collapse__block">
# <!-- Start collapse 1 -->
# <div class="collapse__block-item">
# <div class="collapse__block-title">
# <div class="d-flex">
# <span class="fal fa-phone collapse__block-title--icon"></span> <span class="flex-fill" x-ms-format-detection="none">+1 415-865-0633</span>
# <a class="link js-gtm-link" data-category="restaurant.datasheet" data-cooking-type="japanese" data-event="CTA_tel" data-restaurant-distinction="ONE_STAR" data-restaurant-name="Omakase" href="tel:+1 415-865-0633"></a>
# </div>
# </div>
# </div>
# <!-- End collapse 1 -->
# <!-- Start collapse 2 -->
# <div class="collapse__block-item link-item">
# <div class="collapse__block-title d-flex" data-toggle="collapse" href="#level3">
# <div class="d-flex">
# <span class="fal fa-browser collapse__block-title--icon"></span> <span class="flex-fill">www.omakasesf.com</span>
# </div>
# </div>
# <a class="link js-gtm-link" data-category="restaurant.datasheet" data-cooking-type="japanese" data-event="CTA_website" data-restaurant-distinction="ONE_STAR" data-restaurant-name="Omakase" href="http://www.omakasesf.com" rel="nofollow noopener" target="_blank"></a>
# </div>
# <!-- End collapse 2 -->
# <!-- Start collapse 3 -->
# <div class="collapse__block-item collapse-item">
# <div class="collapse__block-title collapse d-flex" data-toggle="collapse" href="#level2">
# <div class="flex-fill d-flex">
# <span class="fal fa-clock collapse__block-title--icon"></span> <span class="flex-fill">Opening hours</span>
# </div>
# <span class="collapse__block-title--label">
# <i class="icon fal fa-angle-right"></i>
# </span>
# </div>
# <div class="collapse collapse__block-content" id="level2">
# <div class="open__time d-flex">
# <div class="open__time-icon"></div>
# <div class="open__time-hour flex-fill">
# <span>Dinner nightly</span>
# </div>
# </div>
# </div>
# </div>
# <!-- End collapse 3 -->
# </div>
# </div>
# <div class="col-md-6">
# <div class="google-map__static">
# <iframe frameborder="0" src="https://www.google.com/maps/embed/v1/place?key=AIzaSyDvEyVCVpGtn81z5NrMKgdehPsrO9sJiMw&amp;q=37.7707700,-122.4029800"></iframe>
# </div>
# <!-- for Share Social Mobile View -->
# <div id="share-sosial-mobile"></div>
# </div>
# </div>
# </section>
# <!-- End Section -->
# <!-- Start Section -->
# <!-- End Section -->
# <!-- Start Section -->
# <section class="section-main">
# <div class="restaurant-details__guide-experience">
# <div class="restaurant-details__guide-experience--heading">
# <img alt="" class="restaurant-details__guide-experience--image lazy" data-src="/assets/images/bib-michelin-man.svg"/>
# <noscript><img alt="" class="restaurant-details__guide-experience--image" src="/assets/images/bib-michelin-man.svg"/></noscript>
# <h4 class="restaurant-details__guide-experience--title">
#                             Share Your MICHELIN Guide Experience</h4>
# </div>
# <div class="restaurant-details__guide-experience--tagsphotos">
# <div class="restaurant-details__guide-experience--taging">
# <i class="fal fa-camera-alt taging--icon"></i>
#                                 Tag your photos with
#                                 <a href="https://www.instagram.com/explore/tags/yesmichelinguide/" rel="nofollow noopener" target="_blank">
#                                 #yesmichelinguide</a>
#                                 or
#                             </div>
# <div class="row">
# <div class="col-md-6 offset-md-3">
# <a class="btn btn-primary btn-border btn-block" href="https://www.pixlee.gallery/michelinfoodtravel-social" rel="nofollow noopener" target="_blank">
#                                         Upload your photo / video</a>
# </div>
# </div>
# </div>
# <div class="restaurant-details__guide-experience--carousel">
# <div class="experience__panel-feeds js-gallery-wrapper">
# <button class="masthead__gallery-open js-experience-open js-gallery-button" data-target="#galleryPopupExperience" data-toggle="modal" type="button">
# <span class="masthead__gallery-open--number">8</span>
# <span class="masthead__gallery-open--base"></span>
# </button>
# <div class="owl-carousel owl-theme" data-dots="false" data-loop="true" data-nav="false" data-padding="0" data-show-dekstop="2" data-show-mobile="2" data-show-tab="2" data-stage-padding="20" id="js-owl-carousel1">
# <div class="item">
# <div class="instagram-post js-experience-open">
# <img alt="" class="lazy" data-src="https://scontent.cdninstagram.com/v/t51.2885-15/e15/s320x320/83881809_2729528003832263_6958837931615352898_n.jpg?_nc_ht=scontent.cdninstagram.com&amp;_nc_ohc=jkFvoR1Nja8AX8reCE3&amp;oh=77cd3ef04e222c3fde7d59543c483399&amp;oe=5E802440"/>
# <noscript><img alt="" src="https://scontent.cdninstagram.com/v/t51.2885-15/e15/s320x320/83881809_2729528003832263_6958837931615352898_n.jpg?_nc_ht=scontent.cdninstagram.com&amp;_nc_ohc=jkFvoR1Nja8AX8reCE3&amp;oh=77cd3ef04e222c3fde7d59543c483399&amp;oe=5E802440"/></noscript>
# </div>
# </div>
# <div class="item">
# <div class="instagram-post js-experience-open">
# <img alt="" class="lazy" data-src="https://scontent.cdninstagram.com/v/t51.2885-15/e15/s320x320/84409615_772820976454910_4467730465852591196_n.jpg?_nc_ht=scontent.cdninstagram.com&amp;_nc_ohc=2YvfDhITSZkAX8FEhg3&amp;oh=210cca84408dbf4ae02eb715014e0dab&amp;oe=5E832A31"/>
# <noscript><img alt="" src="https://scontent.cdninstagram.com/v/t51.2885-15/e15/s320x320/84409615_772820976454910_4467730465852591196_n.jpg?_nc_ht=scontent.cdninstagram.com&amp;_nc_ohc=2YvfDhITSZkAX8FEhg3&amp;oh=210cca84408dbf4ae02eb715014e0dab&amp;oe=5E832A31"/></noscript>
# </div>
# </div>
# <div class="item">
# <div class="instagram-post js-experience-open">
# <img alt="" class="lazy" data-src="https://scontent.cdninstagram.com/v/t51.2885-15/e35/s320x320/84255600_320728372387192_858975547937543607_n.jpg?_nc_ht=scontent.cdninstagram.com&amp;_nc_ohc=JSMyT9KO1jQAX--GKoY&amp;oh=0c4c3eee19597719c9d46796b3b0d880&amp;oe=5E8B1A99"/>
# <noscript><img alt="" src="https://scontent.cdninstagram.com/v/t51.2885-15/e35/s320x320/84255600_320728372387192_858975547937543607_n.jpg?_nc_ht=scontent.cdninstagram.com&amp;_nc_ohc=JSMyT9KO1jQAX--GKoY&amp;oh=0c4c3eee19597719c9d46796b3b0d880&amp;oe=5E8B1A99"/></noscript>
# </div>
# </div>
# <div class="item">
# <div class="instagram-post js-experience-open">
# <img alt="" class="lazy" data-src="https://scontent.cdninstagram.com/v/t51.2885-15/e15/s320x320/87544999_505873653698206_7776909356235865452_n.jpg?_nc_ht=scontent.cdninstagram.com&amp;_nc_ohc=khftOgeHOd8AX_vVxtv&amp;oh=3712b80f7328b6d46e05d72f40540783&amp;oe=5E827098"/>
# <noscript><img alt="" src="https://scontent.cdninstagram.com/v/t51.2885-15/e15/s320x320/87544999_505873653698206_7776909356235865452_n.jpg?_nc_ht=scontent.cdninstagram.com&amp;_nc_ohc=khftOgeHOd8AX_vVxtv&amp;oh=3712b80f7328b6d46e05d72f40540783&amp;oe=5E827098"/></noscript>
# </div>
# </div>
# <div class="item">
# <div class="instagram-post js-experience-open">
# <img alt="" class="lazy" data-src="https://scontent.cdninstagram.com/v/t51.2885-15/e15/s320x320/87304976_604912440363324_700577904172231484_n.jpg?_nc_ht=scontent.cdninstagram.com&amp;_nc_ohc=XXq0aWsCYGoAX8kupSU&amp;oh=da429e6d6cd27080f16c4f7e0aa16811&amp;oe=5E845C2D"/>
# <noscript><img alt="" src="https://scontent.cdninstagram.com/v/t51.2885-15/e15/s320x320/87304976_604912440363324_700577904172231484_n.jpg?_nc_ht=scontent.cdninstagram.com&amp;_nc_ohc=XXq0aWsCYGoAX8kupSU&amp;oh=da429e6d6cd27080f16c4f7e0aa16811&amp;oe=5E845C2D"/></noscript>
# </div>
# </div>
# <div class="item">
# <div class="instagram-post js-experience-open">
# <img alt="" class="lazy" data-src="https://scontent.cdninstagram.com/v/t51.2885-15/e35/p320x320/87418006_509106920023899_7757467737235903834_n.jpg?_nc_ht=scontent.cdninstagram.com&amp;_nc_ohc=wvktv09niLsAX8Q2FVF&amp;oh=0aa601e555d27cc253747314cb209da8&amp;oe=5E851976"/>
# <noscript><img alt="" src="https://scontent.cdninstagram.com/v/t51.2885-15/e35/p320x320/87418006_509106920023899_7757467737235903834_n.jpg?_nc_ht=scontent.cdninstagram.com&amp;_nc_ohc=wvktv09niLsAX8Q2FVF&amp;oh=0aa601e555d27cc253747314cb209da8&amp;oe=5E851976"/></noscript>
# </div>
# </div>
# <div class="item">
# <div class="instagram-post js-experience-open">
# <img alt="" class="lazy" data-src="https://scontent.cdninstagram.com/v/t51.2885-15/e15/s320x320/83910268_625559501563385_5311325817550537601_n.jpg?_nc_ht=scontent.cdninstagram.com&amp;_nc_ohc=acfgA7LS4P0AX96hV4V&amp;oh=c1cec75e064233315dbe678eec977b1d&amp;oe=5E84ED1B"/>
# <noscript><img alt="" src="https://scontent.cdninstagram.com/v/t51.2885-15/e15/s320x320/83910268_625559501563385_5311325817550537601_n.jpg?_nc_ht=scontent.cdninstagram.com&amp;_nc_ohc=acfgA7LS4P0AX96hV4V&amp;oh=c1cec75e064233315dbe678eec977b1d&amp;oe=5E84ED1B"/></noscript>
# </div>
# </div>
# <div class="item">
# <div class="instagram-post js-experience-open">
# <img alt="" class="lazy" data-src="https://scontent.cdninstagram.com/v/t51.2885-15/e15/s320x320/87239244_682388569170549_2385883125098564991_n.jpg?_nc_ht=scontent.cdninstagram.com&amp;_nc_ohc=Y-06VfYmbTMAX8H85kx&amp;oh=82a8342adcc06f91d7229cef21a5f0da&amp;oe=5E82FF17"/>
# <noscript><img alt="" src="https://scontent.cdninstagram.com/v/t51.2885-15/e15/s320x320/87239244_682388569170549_2385883125098564991_n.jpg?_nc_ht=scontent.cdninstagram.com&amp;_nc_ohc=Y-06VfYmbTMAX8H85kx&amp;oh=82a8342adcc06f91d7229cef21a5f0da&amp;oe=5E82FF17"/></noscript>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="restaurant-details__guide-experience--followus">
# <div class="restaurant-details__guide-experience--followus-text">
# <img alt="" class="restaurant-details__guide-experience--followus-icon lazy" data-src="/assets/images/social-network/instagram.png">
# <noscript><img alt="" class="restaurant-details__guide-experience--followus-icon" src="/assets/images/social-network/instagram.png"/></noscript>
# <a class="experience__panel-footer--follow" href="https://www.instagram.com/michelinguide" rel="nofollow noopener" target="_blank">
#                                         Follow Us on Instagram
#                                     </a>
# </img></div>
# </div>
# </div>
# </section>
# <!-- End Section -->
# </div>
# </div>
# </div>
# <!-- End Section -->
# <!-- Start section desktop -->
# <div class="d-none d-lg-block">
# <!-- Start Section Restaurant Nearby -->
# <section class="section-main">
# <div class="container">
# <div class="section-header have-slider-nav">
# <h2 class="section__heading_title">Nearby Restaurants</h2>
# <div class="btn-carousel hide-not-dekstop">
# <button class="btn btn-outline-secondary btn-sm btn-carousel__link js-prev-carousel" data-target="js-owl-carousel-nearby">
# <span class="icon fal fa-angle-left"></span>
# </button>
# <button class="btn btn-outline-secondary btn-sm btn-carousel__link js-next-carousel" data-target="js-owl-carousel-nearby">
# <span class="icon fal fa-angle-right"></span>
# </button>
# </div>
# </div>
# <div class="section-main-content">
# <div class="owl-mobile-fitwidth owl-card-box">
# <div class="owl-carousel owl-theme" data-mobile-autowidth="true" data-padding="0" id="js-owl-carousel-nearby">
# <div class="item item-menu">
# <div class="card__menu js-restaurant__list_item js-match-height" data-index="" data-lat="37.770634" data-lng="-122.403015">
# <div class="card__menu-image">
# <a aria-label="Open Okane" class="image-wrapper pl-image lazy" data-bg="url(https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/498296_2.jpg)" data-position-x="50" data-position-y="50" href="/en/restaurants?region=california&amp;city=san-francisco">
# <noscript><img alt="" src="https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/498296_2.jpg"/></noscript>
# </a>
# </div>
# <div class="card__menu-content js-match-height-content">
# <div class="card__menu-content--rating d-flex pl-text">
# <i class="fa-michelin">=</i>
# <span>
#                 MICHELIN Guide California 2019
#             </span>
# </div>
# <h5 class="card__menu-content--title last pl-text pl-big">
# <a aria-label="Open Okane" href="/en/california/san-francisco/restaurant/okane">
#                 Okane
#             </a>
# </h5>
# </div>
# <div class="card__menu-footer d-flex js-match-height-footer">
# <div class="card__menu-footer--location flex-fill pl-text">
# <i class="icon fal fa-map-marker-alt"></i>
#             San Francisco
#         </div>
# <div class="card__menu-footer--price pl-text pl-right">
#             Japanese
#         </div>
# </div>
# <a aria-label="Open Okane" class="link" href="/en/california/san-francisco/restaurant/okane"></a>
# </div>
# </div>
# <div class="item item-menu">
# <div class="card__menu js-restaurant__list_item js-match-height" data-index="" data-lat="37.770943" data-lng="-122.402756">
# <div class="card__menu-image">
# <a aria-label="Open Khai" class="image-wrapper pl-image lazy" data-bg="url(https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/525473_2.jpg)" data-position-x="50" data-position-y="50" href="/en/restaurants?region=california&amp;city=san-francisco">
# <noscript><img alt="" src="https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/525473_2.jpg"/></noscript>
# </a>
# </div>
# <div class="card__menu-content js-match-height-content">
# <div class="card__menu-content--rating d-flex pl-text">
# <i class="fa-michelin">‹</i>
# <span>
#                 MICHELIN Guide California 2019
#             </span>
# </div>
# <h5 class="card__menu-content--title last pl-text pl-big">
# <a aria-label="Open Khai" href="/en/california/san-francisco/restaurant/khai">
#                 Khai
#             </a>
# </h5>
# </div>
# <div class="card__menu-footer d-flex js-match-height-footer">
# <div class="card__menu-footer--location flex-fill pl-text">
# <i class="icon fal fa-map-marker-alt"></i>
#             San Francisco
#         </div>
# <div class="card__menu-footer--price pl-text pl-right">
#             Vietnamese
#         </div>
# </div>
# <a aria-label="Open Khai" class="link" href="/en/california/san-francisco/restaurant/khai"></a>
# </div>
# </div>
# <div class="item item-menu">
# <div class="card__menu js-restaurant__list_item js-match-height" data-index="" data-lat="37.7714" data-lng="-122.40539">
# <div class="card__menu-image">
# <a aria-label="Open Bellota" class="image-wrapper pl-image lazy" data-bg="url(https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/503273_1.jpg)" data-position-x="50" data-position-y="50" href="/en/restaurants?region=california&amp;city=san-francisco">
# <noscript><img alt="" src="https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/503273_1.jpg"/></noscript>
# </a>
# </div>
# <div class="card__menu-content js-match-height-content">
# <div class="card__menu-content--rating d-flex pl-text">
# <i class="fa-michelin">‹</i>
# <span>
#                 MICHELIN Guide California 2019
#             </span>
# </div>
# <h5 class="card__menu-content--title last pl-text pl-big">
# <a aria-label="Open Bellota" href="/en/california/san-francisco/restaurant/bellota">
#                 Bellota
#             </a>
# </h5>
# </div>
# <div class="card__menu-footer d-flex js-match-height-footer">
# <div class="card__menu-footer--location flex-fill pl-text">
# <i class="icon fal fa-map-marker-alt"></i>
#             San Francisco
#         </div>
# <div class="card__menu-footer--price pl-text pl-right">
#             Spanish
#         </div>
# </div>
# <a aria-label="Open Bellota" class="link" href="/en/california/san-francisco/restaurant/bellota"></a>
# </div>
# </div>
# <div class="item item-menu">
# <div class="card__menu js-restaurant__list_item js-match-height" data-index="" data-lat="37.76314" data-lng="-122.40833">
# <div class="card__menu-image">
# <a aria-label="Open The Morris" class="image-wrapper pl-image lazy" data-bg="url(https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/534907_2.jpg)" data-position-x="50" data-position-y="50" href="/en/restaurants?region=california&amp;city=san-francisco">
# <noscript><img alt="" src="https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/534907_2.jpg"/></noscript>
# </a>
# </div>
# <div class="card__menu-content js-match-height-content">
# <div class="card__menu-content--rating d-flex pl-text">
# <i class="fa-michelin">‹</i>
# <span>
#                 MICHELIN Guide California 2019
#             </span>
# </div>
# <h5 class="card__menu-content--title last pl-text pl-big">
# <a aria-label="Open The Morris" href="/en/california/san-francisco/restaurant/the-morris">
#                 The Morris
#             </a>
# </h5>
# </div>
# <div class="card__menu-footer d-flex js-match-height-footer">
# <div class="card__menu-footer--location flex-fill pl-text">
# <i class="icon fal fa-map-marker-alt"></i>
#             San Francisco
#         </div>
# <div class="card__menu-footer--price pl-text pl-right">
#             Contemporary
#         </div>
# </div>
# <a aria-label="Open The Morris" class="link" href="/en/california/san-francisco/restaurant/the-morris"></a>
# </div>
# </div>
# <div class="item item-menu">
# <div class="card__menu js-restaurant__list_item js-match-height" data-index="" data-lat="37.778885" data-lng="-122.39721">
# <div class="card__menu-image">
# <a aria-label="Open Cockscomb" class="image-wrapper pl-image lazy" data-bg="url(https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/468673_2.jpg)" data-position-x="50" data-position-y="50" href="/en/restaurants?region=california&amp;city=san-francisco">
# <noscript><img alt="" src="https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/468673_2.jpg"/></noscript>
# </a>
# </div>
# <div class="card__menu-content js-match-height-content">
# <div class="card__menu-content--rating d-flex pl-text">
# <i class="fa-michelin">‹</i>
# <span>
#                 MICHELIN Guide California 2019
#             </span>
# </div>
# <h5 class="card__menu-content--title last pl-text pl-big">
# <a aria-label="Open Cockscomb" href="/en/california/san-francisco/restaurant/cockscomb">
#                 Cockscomb
#             </a>
# </h5>
# </div>
# <div class="card__menu-footer d-flex js-match-height-footer">
# <div class="card__menu-footer--location flex-fill pl-text">
# <i class="icon fal fa-map-marker-alt"></i>
#             San Francisco
#         </div>
# <div class="card__menu-footer--price pl-text pl-right">
#             American
#         </div>
# </div>
# <a aria-label="Open Cockscomb" class="link" href="/en/california/san-francisco/restaurant/cockscomb"></a>
# </div>
# </div>
# <div class="item item-menu">
# <div class="card__menu js-restaurant__list_item js-match-height" data-index="" data-lat="37.77368" data-lng="-122.39152">
# <div class="card__menu-image">
# <a aria-label="Open Casey's Pizza" class="image-wrapper pl-image lazy" data-bg="url(https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/558693_1.jpg)" data-position-x="50" data-position-y="50" href="/en/restaurants?region=california&amp;city=san-francisco">
# <noscript><img alt="" src="https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/558693_1.jpg"/></noscript>
# </a>
# </div>
# <div class="card__menu-content js-match-height-content">
# <div class="card__menu-content--rating d-flex pl-text">
# <i class="fa-michelin">‹</i>
# <span>
#                 MICHELIN Guide California 2019
#             </span>
# </div>
# <h5 class="card__menu-content--title last pl-text pl-big">
# <a aria-label="Open Casey's Pizza" href="/en/california/san-francisco/restaurant/casey-s-pizza">
#                 Casey's Pizza
#             </a>
# </h5>
# </div>
# <div class="card__menu-footer d-flex js-match-height-footer">
# <div class="card__menu-footer--location flex-fill pl-text">
# <i class="icon fal fa-map-marker-alt"></i>
#             San Francisco
#         </div>
# <div class="card__menu-footer--price pl-text pl-right">
#             Pizza
#         </div>
# </div>
# <a aria-label="Open Casey's Pizza" class="link" href="/en/california/san-francisco/restaurant/casey-s-pizza"></a>
# </div>
# </div>
# <div class="item item-menu">
# <div class="card__menu js-restaurant__list_item js-match-height" data-index="" data-lat="37.7623" data-lng="-122.39714">
# <div class="card__menu-image">
# <a aria-label="Open Papito" class="image-wrapper pl-image lazy" data-bg="url(https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/325319_2.jpg)" data-position-x="50" data-position-y="50" href="/en/restaurants?region=california&amp;city=san-francisco">
# <noscript><img alt="" src="https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/325319_2.jpg"/></noscript>
# </a>
# </div>
# <div class="card__menu-content js-match-height-content">
# <div class="card__menu-content--rating d-flex pl-text">
# <i class="fa-michelin">‹</i>
# <span>
#                 MICHELIN Guide California 2019
#             </span>
# </div>
# <h5 class="card__menu-content--title last pl-text pl-big">
# <a aria-label="Open Papito" href="/en/california/san-francisco/restaurant/papito">
#                 Papito
#             </a>
# </h5>
# </div>
# <div class="card__menu-footer d-flex js-match-height-footer">
# <div class="card__menu-footer--location flex-fill pl-text">
# <i class="icon fal fa-map-marker-alt"></i>
#             San Francisco
#         </div>
# <div class="card__menu-footer--price pl-text pl-right">
#             Mexican
#         </div>
# </div>
# <a aria-label="Open Papito" class="link" href="/en/california/san-francisco/restaurant/papito"></a>
# </div>
# </div>
# <div class="item item-menu">
# <div class="card__menu js-restaurant__list_item js-match-height" data-index="" data-lat="37.76858" data-lng="-122.415115">
# <div class="card__menu-image">
# <a aria-label="Open Izakaya Rintaro" class="image-wrapper pl-image lazy" data-bg="url(https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/468661_1.jpg)" data-position-x="50" data-position-y="50" href="/en/restaurants?region=california&amp;city=san-francisco">
# <noscript><img alt="" src="https://d3h1lg3ksw6i6b.cloudfront.net/guide/xlarge/468661_1.jpg"/></noscript>
# </a>
# </div>
# <div class="card__menu-content js-match-height-content">
# <div class="card__menu-content--rating d-flex pl-text">
# <i class="fa-michelin">=</i>
# <span>
#                 MICHELIN Guide California 2019
#             </span>
# </div>
# <h5 class="card__menu-content--title last pl-text pl-big">
# <a aria-label="Open Izakaya Rintaro" href="/en/california/san-francisco/restaurant/izakaya-rintaro">
#                 Izakaya Rintaro
#             </a>
# </h5>
# </div>
# <div class="card__menu-footer d-flex js-match-height-footer">
# <div class="card__menu-footer--location flex-fill pl-text">
# <i class="icon fal fa-map-marker-alt"></i>
#             San Francisco
#         </div>
# <div class="card__menu-footer--price pl-text pl-right">
#             Japanese
#         </div>
# </div>
# <a aria-label="Open Izakaya Rintaro" class="link" href="/en/california/san-francisco/restaurant/izakaya-rintaro"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- End Section Restaurant Nearby -->
# <!-- Start Section -->
# <section class="section-main last">
# <div class="container">
# <div class="section-header have-slider-nav">
# <h2 class="section__heading_title">Related Reads</h2>
# </div>
# <div class="section-main-content">
# <div class="owl-mobile-fitwidth owl-card-box">
# <div class="owl-carousel owl-theme" data-dots="false" data-mobile-autowidth="true" data-nav="false" data-padding="0" id="js-owl-carousel3">
# <div class="item">
# <div class="card-post">
# <a aria-label="Read more about 5 San Francisco Restaurant Openings to Know About" class="image-wrapper lazy" data-bg="url(https://d3h1lg3ksw6i6b.cloudfront.net/media/image/2019/01/29/9d9fb4e6e2e74659abfefabb2a387e20_sf_openings_winter_2019_udontime_credit_facebook_HERO.jpg)" data-position-x="50" data-position-y="50" href="/en/article/dining-out/san-francisco-restaurant-openings-udon-time-obispo-verjus">
# <noscript><img alt="" src="https://d3h1lg3ksw6i6b.cloudfront.net/media/image/2019/01/29/9d9fb4e6e2e74659abfefabb2a387e20_sf_openings_winter_2019_udontime_credit_facebook_HERO.jpg"/></noscript>
# </a>
# <div class="card-post__content-wrapper">
# <div class="card-post__sub-content">
# <a aria-label="All articles of Dining Out" class="link link-secondary card-post__sub-link" href="/en/articles/dining-out">
#                         Dining Out</a>
# <span class="no-wrap card-post__reading-time">
# <i class="fal fa-clock"></i>
#
#                             2 minutes
#
#                     </span>
# </div>
# <h5 class="card-post__title js-match-height-title">
# <a aria-label="Read more about 5 San Francisco Restaurant Openings to Know About" class="clamp-2" href="/en/article/dining-out/san-francisco-restaurant-openings-udon-time-obispo-verjus">
#                     5 San Francisco Restaurant Openings to Know About
#                 </a>
# </h5>
# <div class="card-post__content js-match-height-content">
# <p class="clamp-3">From fast-casual mega projects to a widely-anticipated rum bar, here are five new restaurants in San Francisco ripe for the taking.</p>
# </div>
# </div>
# <div class="card-post__footer js-match-height-footer">
# <div class="card-post__tags">
# <a aria-label="All articles of new opening" class="btn btn-outline-secondary btn-sm" href="/en/tags/new%20opening">
#                         new opening
#                     </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- End Short Post -->
# </div>
# <!-- End section desktop -->
# <!-- Start section mobile -->
# <div class="d-block d-lg-none">
# <section class="section-main last">
# <div class="container">
# <div class="row">
# <div class="col-md-6 offset-md-3">
# <div class="restaurant-details__button--mobile">
# <a class="btn btn-primary btn-border btn-icon-left btn-block" href="/en/california/san-francisco/restaurants?lat=37.7707700&amp;lon=-122.4029800"><i class="fal fa-utensils"></i>
#                                     Find Nearby Restaurant</a>
# <a class="btn btn-primary btn-border btn-icon-left btn-block" href="/en/search?q=Omakase&amp;type=article&amp;locations=california%2Fsan-francisco"><i class="fal fa-newspaper"></i>
# ...
#                                             </a>
# </li>
# <li class="">
# <a class="js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="CountrySelection.iceland.english" data-guide="Global" href="/is/en">
#                                                 Iceland
#                                             </a>
# </li>
# <li class="">
# <a class="js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="CountrySelection.italia.italiano" data-guide="Global" href="/it/it">
#                                                 Italia | Italiano
#                                             </a>
# </li>
# <li class="">
# <a class="js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="CountrySelection.italia.english" data-guide="Global" href="/it/en">
#                                                 Italia | English
#                                             </a>
# </li>
# <li class="">
# <a class="js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="CountrySelection.luxembourg.english" data-guide="Global" href="https://fr.viamichelin.be/web/Restaurants/Restaurants-Luxembourg" rel="nofollow noopener" target="_blank">
#                                                 Luxembourg
#                                             </a>
# </li>
# <li class="">
# <a class="js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="CountrySelection.netherlands.english" data-guide="Global" href="https://www.viamichelin.nl/web/Restaurants/Restaurants-Nederland" rel="nofollow noopener" target="_blank">
#                                                 Netherlands
#                                             </a>
# </li>
# <li class="">
# <a class="js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="CountrySelection.norway.english" data-guide="Global" href="/no/en">
#                                                 Norway
#                                             </a>
# </li>
# <li class="">
# <a class="js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="CountrySelection.poland.english" data-guide="Global" href="/pl/en">
#                                                 Poland
#                                             </a>
# </li>
# <li class="">
# <a class="js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="CountrySelection.portugal.english" data-guide="Global" href="https://www.viamichelin.pt/web/Restaurantes/Restaurantes-Portugal" rel="nofollow noopener" target="_blank">
#                                                 Portugal
#                                             </a>
# </li>
# <li class="">
# <a class="js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="CountrySelection.republic_of_ireland.english" data-guide="Global" href="/ie/en">
#                                                 Republic of Ireland
#                                             </a>
# </li>
# <li class="">
# <a class="js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="CountrySelection.españa.español" data-guide="Global" href="/es/es">
#                                                 España | Español
#                                             </a>
# </li>
# <li class="">
# <a class="js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="CountrySelection.españa.english" data-guide="Global" href="/es/en">
#                                                 España | English
#                                             </a>
# </li>
# <li class="">
# <a class="js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="CountrySelection.sweden.english" data-guide="Global" href="/se/en">
#                                                 Sweden
#                                             </a>
# </li>
# <li class="">
# <a class="js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="CountrySelection.switzerland.français" data-guide="Global" href="/ch/fr">
#                                                 Switzerland | Français
#                                             </a>
# </li>
# <li class="">
# <a class="js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="CountrySelection.switzerland.deutsch" data-guide="Global" href="/ch/de">
#                                                 Switzerland | Deutsch
#                                             </a>
# </li>
# <li class="">
# <a class="js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="CountrySelection.switzerland.italiano" data-guide="Global" href="/ch/it">
#                                                 Switzerland | Italiano
#                                             </a>
# </li>
# <li class="">
# <a class="js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="CountrySelection.switzerland.english" data-guide="Global" href="/ch/en">
#                                                 Switzerland | English
#                                             </a>
# </li>
# <li class="">
# <a class="js-gtm-link" data-category="restaurant.datasheet" data-country="en" data-event="CountrySelection.united_kingdom.english" data-guide="Global" href="/gb/en">
#                                                 United Kingdom
#                                             </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </section>
# </div>
# <!-- End data location -->
# <div aria-hidden="true" aria-labelledby="Subscription popup" class="modal fade in subscription-popup__dialog js-subs__modal" role="dialog" tabindex="-1">
# <div class="modal-dialog modal-lg">
# <div class="modal-content subscription-popup">
# <div class="subscription-popup__content">
# <div class="row row-no-gutters">
# <div class="col-lg-8 col-md-12">
# <div class="subscription-popup__main">
# <div class="subscription-popup__main">
# <h3 class="subscription-popup__title">
#                                         Stay current with the MICHELIN Guide news
#                                     </h3>
# <p class="subscription-popup__subtitle">
#                                         Receive the latest MICHELIN Guide stories, most exclusive restaurant offers and events from your city and beyond.
#                                     </p>
# </div>
# </div>
# <div class="subscription-popup__action">
# <div class="form-group subscription-popup__action--button">
# <a class="btn btn-primary btn-block" href="/en/subscribe">
#                                         Subscribe now
#                                     </a>
# </div>
# <div class="subscription-popup__action--link">
# <a class="js-subscribe__dismiss" data-url="/en/subscribe/dismiss" href="javascript:void(0);">
#                                         Maybe Later
#                                     </a>
# </div>
# </div>
# </div>
# <div class="col-lg-4 d-none d-lg-block">
# <div class="subscription-popup__img">
# <img alt="" class="lazy" data-src="/assets/images/istock-536080395.png">
# </img></div>
# </div>
# </div>
# </div>
# <div class="subscription-popup__img subscription-popup__img--mobile">
# <img alt="" class="lazy" data-src="/assets/images/iStock-183752283-2.png">
# </img></div>
# </div>
# </div>
# </div>
# <script id="autocomplete-header-template" type="text/template">
# <div class="typeahead__group">
#     <a tabindex="-1">
#         <div class="typeahead__group-heading">
#             <i class="fal {{icon}} typeahead__group-icon link-gray"></i>
#             <h6 class="typeahead__item-title">{{label}}</h6>
#         </div>
#     </a>
# </div>
# </script>
# <script id="autocomplete-see-all-restaurant-template" type="text/template">
# <div class="typeahead__link">
#     <a href="{{url}}" tabindex="-1">
#         <strong>See all</strong> ({{total}} restaurants)
#     </a>
# </div>
# </script>
# <script id="autocomplete-find-restaurants-template" type="text/template">
# <div class="typeahead__link typeahead__link-empty js-autocomplete__empty">
#     <a href="/en/restaurants" tabindex="-1">
#         <i class="fal fa-crosshairs icon"></i>
#         <strong>Find restaurants near me</strong>
#     </a>
# </div>
# </script>
# <script id="autocomplete-location-item-template" type="text/template">
# <div class="typeahead__item typeahead__group-location" style="white-space: normal;">
#     <a href="{{url}}">
#         <div class="typeahead">
#             <div class="typeahead__item-title-container">
#                 <h6 class="typeahead__item-title clamp-2"
#                     style="overflow: hidden; text-overflow: ellipsis; -webkit-box-orient: vertical; display: -webkit-box; -webkit-line-clamp: 2;">
#                     {{{label}}}
#                 </h6>
#             </div>
#             <div class="typeahead__item-location">
#                 See all
#             </div>
#         </div>
#     </a>
# </div>
# </script>
# <script id="autocomplete-other-item-template" type="text/template">
# <div class="typeahead__item typeahead__group-restaurant" style="white-space: normal;">
#     <a href="{{url}}">
#         <div class="typeahead">
#             <div class="typeahead__item-title-container">
#                 <h6 class="typeahead__item-title clamp-2"
#                     style="overflow: hidden; text-overflow: ellipsis; -webkit-box-orient: vertical; display: -webkit-box; -webkit-line-clamp: 2;">
#                     <i class="fa-michelin typeahead__item-distinction">{{icon}}</i> {{{label}}}
#                     <div class="typeahead__item-sub-title-container">
#                         <div class="typeahead__item-sub-title">{{{city}}}, {{{country}}}</div>
#                     </div>
#                 </h6>
#             </div>
#             {{#distance}}
#             <div class="typeahead__item-location">
#                 <i class="fal fa-map-marker-alt"></i>
#                 <span class="typeahead__item-location--remarks">{{distance}} km</span>
#             </div>
#             {{/distance}}
#         </div>
#     </a>
# </div>
# </script>
# <script id="restaurant-card-template" type="text/template">
# <div class="card__menu js-restaurant__list_item js-match-height js-map" data-index="{{index}}" data-lat="{{lat}}" data-lng="{{lng}}">
#     <div class="card__menu-image">
#         <a href="{{url}}" class="image-wrapper pl-image lazy" aria-label="Open {{name}}"
#            data-position-x="50" data-position-y="50" data-bg="url({{image}})">
#             <noscript><img src="{{image}}" alt=""></noscript>
#         </a>
#     </div>
#     <div class="card__menu-content js-match-height-content">
#         <div class="card__menu-content--rating d-flex pl-text">
#             <i class="fa-michelin">{{icon}}</i>
#             <span>
#                 MICHELIN Guide {{site}} {{year}}
#             </span>
#         </div>
#         <h5 class="card__menu-content--title {{^onlineBooking}}last{{/onlineBooking}} pl-text pl-big">
#             <a href="{{url}}" aria-label="Open {{name}}">{{name}}</a>
#         </h5>
#         {{#offers}}
#         <div class="color-primary card__menu-content--experiences last pl-text">
#             {{#singleOffer}}
#             {{offersSize}} offer available
#             {{/singleOffer}}
#             {{^singleOffer}}
#             {{offersSize}} offers available
#             {{/singleOffer}}
#         </div>
#         {{/offers}}
#         {{^offers}}
#         {{#onlineBooking}}
#         <div class="color-primary card__menu-content--reservations last pl-text">
#             Reservations available
#         </div>
#         {{/onlineBooking}}
#         {{/offers}}
#     </div>
#     <div class="card__menu-footer d-flex">
#         <div class="card__menu-footer--location flex-fill pl-text">
#             <i class="icon fal fa-map-marker-alt"></i> {{city}}
#         </div>
#         <div class="card__menu-footer--price pl-text pl-right">
#             {{cuisine}}
#         </div>
#     </div>
#     <a href="{{url}}" class="link" aria-label="Open {{name}}"></a>
# </div>
# </script>
# <script id="facet-template" type="text/template">
# <div class="form-check">
#     <input class="form-check-input" type="checkbox" value="{{value}}"
#            data-value="{{value}}" {{#isRefined}}checked{{/isRefined}} {{#disabled}}disabled{{/disabled}}>
#     <label class="form-check-label"><span class="svg-icon">{{{checkboxIcon}}}</span>{{{label}}} ({{count}})</label>
# </div>
# </script>
# <script id="subscription-box-template" type="text/template">
# <div class="col-lg-12">
#     <!-- Start subscribe Box -->
# <div class="subscribe__box js-subscription__box">
#     <h3 class="subscribe__box-title">The best of the MICHELIN Experience in your inbox</h3>
#     <p class="subscribe__box-desc">Stay on the top of the best restaurants, offers, lifestyle, and events recommended in our guide cities.</p>
#     <a href="/en/subscribe" class="btn btn-primary btn-more">
#         Subscribe
#     </a>
# </div>
# <!-- End subscribe Box -->
# </div>
# </script>
# <script type="text/javascript">
#     var AWARDS = [];
#     var RESTAURANT_RATINGS = [];
#     var COUNTRIES_MAP = {};
#     var REGIONS_MAP = {};
#     var CITIES_MAP = {};
#     var AREAS_MAP = {};
#     var AWARDS_MAP = {"THREE_STARS":{"icon":"o","label":"3 Stars MICHELIN","gtmLabel":"1 star","slug":"3-stars-michelin"},"TWO_STARS":{"icon":"n","label":"2 Stars MICHELIN","gtmLabel":"2 star","slug":"2-stars-michelin"},"MICHELIN_PLATE":{"icon":"\u2039","label":"The Plate MICHELIN","gtmLabel":"plate","slug":"the-plate-michelin"},"ONE_STAR":{"icon":"m","label":"1 Star MICHELIN","gtmLabel":"3 star","slug":"1-star-michelin"},"BIB_GOURMAND":{"icon":"=","label":"Bib Gourmand","gtmLabel":"bib","slug":"bib-gourmand"}};
#     var CUISINES_MAP = {};
#     var RESTAURANT_SERVICES_MAP = {};
#     var RESTAURANT_RATINGS_MAP = {};
#     var RESTAURANT_PLACEHOLDER_IMAGES = ["https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/default1.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/default2.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-119577476.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-157185809.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-179536318.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-182146474.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-509105428.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-542825520.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-544123256.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-677785016.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-810733288.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/iStock-839150516.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/online_list_default_0.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/online_list_default_1.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_0.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_1.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_2.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_3.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_5.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_6.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_7.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_9.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_10.jpg","https://d3h1lg3ksw6i6b.cloudfront.net/guide/placeholder/pic_poilist_default_11.jpg"];
#     function initEmptyMap() {
#         var mapContainer = document.getElementById('algoliasearchMap');
#         if (mapContainer) new google.maps.Map(mapContainer, {});
#     }
# </script>
# <script src="https://polyfill.io/v3/polyfill.min.js?features=default,Array.prototype.find,Array.prototype.includes"></script>
# <script charset="utf-8" src="/assets/web/app.guide-289eab169a8ce5de6ba324bd60894f99.js" type="text/javascript"></script>
# <!-- Dynamic Tag Management -->
# <script>
#         _satellite.pageBottom();
#     </script>
# <!-- End Dynamic Tag Management -->
# </body>
# </html>

# %%
soup.select('title')
# Out:
# [<title>Omakase – San Francisco - a MICHELIN Guide Restaurant</title>,
#  <title>MICHELIN Guide - the official website</title>]

# %%
star_dict = {
    'm': 1,
    'n': 2,
    'o': 3
}

utensil_dict = {
    2: 0, #simple shop
    'ò': 1, #Comfortable
    'ó': 2, #Quite Comfortable
    'ô': 3, #Very Comfortable
    'õ': 4, #Top class comfortable
    'ö': 5 #Luxury in the traditional style
}


def num_stars(site):
    content = site.find('i', 'fa-michelin restaurant-details__classification--list-icon color-primary').contents
    letter = content[0]
    return star_dict[letter]

# %%
def get_address(site):
    content = soup.find('ul', 'restaurant-details__heading--list').contents
    inner = res_heading[1].contents
    
    return inner[1]

# %%
def remove_space_lines(text):
    pattern1 = re.compile(r'[\s\s+]')
    return re.sub(pattern1, '', text)

# %%
def split_money(text):
    currency = text[-3:]
    
    money = text[:-3]    
    money = money.split('-')
    
    min_price = money[0]
    max_price = money[1]
    
    money_series = pd.Series({'min_price': min_price, 'max_price': max_price, 'currency': currency})
    
    return money_series

# %%
def get_price_cuisine(site):
    content = soup.find('li', 'restaurant-details__heading-price').contents[0]
    content = content.strip()
    content = remove_space_lines(content)
    
    content = content.split('•')
    
    money_series = split_money(content[0])
    
    cuisine = pd.Series(content[1], index = ['cuisine'])
    
    money_series = money_series.append(cuisine)
    
    return money_series

# %%
get_price_cuisine(soup)
# Out:
# min_price          75
# max_price         150
# currency          USD
# cuisine      Japanese
# dtype: object

# %%
def get_description(site):
    contents = soup.find('div', 'js-show-description-text').contents[1].contents[0]
    return unicodedata.normalize('NFKD', contents)

# %%
def get_star_comfort(site):
    content = site.find_all('i', "fa-michelin restaurant-details__classification--list-icon color-primary")
    
    #If the restaurant is marked as "delightful," the utensils are also in 'primary' color:
    if len(content) == 2:
        star_content = content[0].contents
        star_letter = star_content[0]
        
        utensil_content = content[1]
        utensil_letter = utensil_content.contents[0]
        
        star_comfort_series = pd.Series({'star': star_dict[star_letter], 'comfort': utensil_dict[utensil_letter],
                                        'delightful': 1})
        

    #If the restaurant does not have 'delightful' distinction, utensils are black:
    if len(content) == 1:
        content_black = site.find_all('i', "fa-michelin restaurant-details__classification--list-icon color-black")
        star_content = content[0].contents
        star_letter = star_content[0]        
        
        utensil_content = content_black[0]
        utensil_letter = utensil_content.contents[0]
        
        star_comfort_series = pd.Series({'star': star_dict[star_letter], 'comfort': utensil_dict[utensil_letter],
                                        'delightful': 0})
    
    
    return star_comfort_series

# %%
def get_restaurant_servies(site):
    services = []
    content = soup.find_all('div', "restaurant-details__services--content")
    
    for item in content:
        service = item.contents[2].strip()
        services.append(service)
        
    return services

# %%
def get_restaurant_info(site):
    content = site.find_all('span', 'flex-fill')
    hours_content = site.find('div', 'open__time-hour flex-fill')
    
    phone = content[0].contents[0]
    website = content[1].contents[0]
    hours = hours_content.contents[1].contents[0]

    info_series = pd.Series({'phone': phone, 'website': website, 'hours': hours})
    
    return info_series

# %%
get_restaurant_info(soup)
# Out:
# phone        +1 415-865-0633
# website    www.omakasesf.com
# hours         Dinner nightly
# dtype: object

# %%
def get_lon_lat(site):
    content = site.find_all('iframe')
    link = content[1]['src']
    
    coordinates = link.split('=')[2]
    coordinates = coordinates.split(',')
    
    latitude = float(coordinates[0])
    longitude = float(coordinates[1])
    
    lon_lat_series = pd.Series({'lat': latitude, 'lon': longitude})
    
    return lon_lat_series

# %%
get_lon_lat(soup)
# Out:
# lat     37.77077
# lon   -122.40298
# dtype: float64

# %%
a = soup.find_all('iframe')

# %%
b = a[1]['src']

# %%
b
# Out:
# 'https://www.google.com/maps/embed/v1/place?key=AIzaSyDvEyVCVpGtn81z5NrMKgdehPsrO9sJiMw&q=37.7707700,-122.4029800'

# %%
b.split('=')[2]
# Out:
# '37.7707700,-122.4029800'
